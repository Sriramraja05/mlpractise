# %% [markdown]
# <a href="https://colab.research.google.com/github/Sriramraja05/mlpractise/blob/main/01-LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Linear Regression

# %%
# !pip install pandas
# !pip install numpy
# !pip install -U scikit-learn
# !pip install -U matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
#Mount a google drive
from google.colab import drive 
drive.mount('/content/gdrive')

#Read file from local drive, The dataset were contains the world population from 1960 - 2011
df=pd.read_csv('gdrive/My Drive/MlPractise/Dataset/worldPopulation.csv', #Path of the CSV file
               on_bad_lines='skip', # to skip the bad line error
               sep='\t' #reads the csv as df to split by tab 
               )
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2012         2013         2014         2015  \
# ...

# %%
# Data cleaning
# replacing blank spaces with '_' 
df.columns =[column.replace(" ", "_") for column in df.columns]

#Filter only indian data
indian_population = df.query("Country_Name=='India'")

indian_population.head()
# Out:
#     Country_Name Country_Code     Indicator_Name Indicator_Code         1960  \
# 109        India          IND  Population, total    SP.POP.TOTL  445954579.0
#
#             1961         1962         1963         1964         1965  ...  \
# 109  456351876.0  467024193.0  477933619.0  489059309.0  500114346.0  ...
#
#              2012          2013          2014          2015          2016  \
# 109  1.274487e+09  1.291132e+09  1.307247e+09  1.322867e+09  1.338636e+09
#
#              2017          2018          2019          2020          2021
# 109  1.354196e+09  1.369003e+09  1.383112e+09  1.396387e+09  1.407564e+09
#
# [1 rows x 66 columns]
